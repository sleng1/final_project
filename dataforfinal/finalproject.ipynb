# %%
import pandas

# %%
nba_table = pandas.read_csv('2024_playoffs_data.csv')
nba_table
# Out:
#       Rank                   Player Team   Age    GP  Wins  Losses   MIN  \
# 0      1.0              Joel Embiid  PHI  30.0   6.0   2.0     4.0  41.4
# 1      2.0            Jalen Brunson  NYK  27.0  13.0   7.0     6.0  39.8
# 2      3.0           Damian Lillard  MIL  33.0   4.0   1.0     3.0  39.1
# 3      4.0  Shai Gilgeous-Alexander  OKC  25.0  10.0   6.0     4.0  39.9
# 4      5.0             Tyrese Maxey  PHI  23.0   6.0   2.0     4.0  44.6
# ..     ...                      ...  ...   ...   ...   ...     ...   ...
# 212  197.0  Olivier-Maxence Prosper  DAL  21.0   1.0   0.0     1.0   0.9
# 213  197.0         Orlando Robinson  MIA  23.0   1.0   0.0     1.0   2.5
# 214  197.0              T.J. Warren  MIN  30.0   3.0   2.0     1.0   3.8
# 215  197.0           Thaddeus Young  PHX  35.0   1.0   0.0     1.0   3.6
# 216  197.0   Thanasis Antetokounmpo  MIL  31.0   2.0   0.0     2.0   2.4
#
#       PTS   FGM  ...   REB  AST  TOV  STL  BLK   PF    FP  DD2  TD3  PlusMinus
# ...
